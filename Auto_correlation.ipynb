# %%
# %matplotlib inline
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display

# %%
x, f = librosa.load('c_strum.wav')
librosa.display.waveplot(x, f)

# %%
# Calculate Autocorrelation by numpy
r = numpy.correlate(x, x, mode='full')[len(x)-1:]
plt.plot(r[:10000])

# %%
# Calculate Autocorrelation by librosa
r = librosa.autocorrelate(x, max_size=10000)
plt.plot(r)
